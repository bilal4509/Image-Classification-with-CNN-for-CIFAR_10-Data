# %% [markdown]
# # Ödev-022-Image Classification with CNN for CIFAR_10 Data

# %%
import tensorflow as tf

mnist=tf.keras.datasets.mnist
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

train_images=train_images/255.0   #normalizasyon
test_images=test_images/255.0

#BÜTÜN RAKAMLARI 0 İLE 1 ARASINDA OLMASI İÇİN 255 YE BÖLDÜK

# %%
from tensorflow.keras.datasets import cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [raw]
# Başarı Oranını artırmanın Yolları
# 1-Layer(katman sayısını arttırmak veya azaltmak)
# 2-Nöron sayısını arttırmak
# 3-Resmler için CNN kullanmak
# 4-Dropout Layer ı ekleme veri kaynağını kesme
# 5-Batch Normalization
# 6-Transfer learning-Başkalarının eğittiği modelleri tekrar kendi modelimizle eğitiyoruz
# 7-Epoch sayısını arttırmak

# %%
train_images = train_images.reshape(60000, 784)
test_images = test_images.reshape(10000, 784)
test_images = test_images.astype("float32")
train_images = train_images.astype("float32")

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation = "relu", input_shape =(784,)),
    tf.keras.layers.Dense(64, activation = "relu"),
    tf.keras.layers.Dense(10, activation = "softmax")])
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size = 120, epochs=40, verbose = 1, validation_data = (test_images, test_labels))
# Out:
# Epoch 1/40
# 500/500 [==============================] - 2s 3ms/step - loss: 0.3796 - accuracy: 0.8916 - val_loss: 0.1808 - val_accuracy: 0.9462
# Epoch 2/40
# 500/500 [==============================] - 2s 4ms/step - loss: 0.1602 - accuracy: 0.9530 - val_loss: 0.1387 - val_accuracy: 0.9599
# Epoch 3/40
# 500/500 [==============================] - 1s 3ms/step - loss: 0.1211 - accuracy: 0.9640 - val_loss: 0.1244 - val_accuracy: 0.9626
# Epoch 4/40
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0972 - accuracy: 0.9714 - val_loss: 0.1101 - val_accuracy: 0.9675
# Epoch 5/40
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0831 - accuracy: 0.9746 - val_loss: 0.1005 - val_accuracy: 0.9705
# Epoch 6/40
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0700 - accuracy: 0.9785 - val_loss: 0.0975 - val_accuracy: 0.9706
# Epoch 7/40
# ...

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print("Accuracy =  %2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1438 - accuracy: 0.9765
# Accuracy =  97.649997

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(512, activation = "relu", input_shape =(784,)),
    tf.keras.layers.Dense(512, activation = "relu"),
    tf.keras.layers.Dense(512, activation = "relu"),
    tf.keras.layers.Dense(10, activation = "softmax")])
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size = 120, epochs=10, verbose = 1, validation_data = (test_images, test_labels))


#bilgisayar donduğu için tekrar başlattım geç kalmamak için  epochs=10 aldım
# Out:
# Epoch 1/10
# 500/500 [==============================] - 10s 19ms/step - loss: 0.2117 - accuracy: 0.9364 - val_loss: 0.1233 - val_accuracy: 0.9627
# Epoch 2/10
# 500/500 [==============================] - 9s 18ms/step - loss: 0.0811 - accuracy: 0.9752 - val_loss: 0.0828 - val_accuracy: 0.9744
# Epoch 3/10
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0538 - accuracy: 0.9832 - val_loss: 0.0984 - val_accuracy: 0.9701
# Epoch 4/10
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0396 - accuracy: 0.9871 - val_loss: 0.0735 - val_accuracy: 0.9780
# Epoch 5/10
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0332 - accuracy: 0.9894 - val_loss: 0.0793 - val_accuracy: 0.9777
# Epoch 6/10
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0256 - accuracy: 0.9920 - val_loss: 0.1003 - val_accuracy: 0.9762
# Epoch 7/10
# ...

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print("Accuracy =  %2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1051 - accuracy: 0.9783
# Accuracy =  97.829998

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape(60000, 28, 28, 1)
test_images = test_images.reshape(10000, 28, 28, 1)

train_images, test_images = train_images / 255.0, test_images / 255.0

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation = "relu", input_shape =(28,28,1)),
    tf.keras.layers.Conv2D(64, (3,3), activation = "relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation = "relu"),
    tf.keras.layers.Dense(10, activation = "softmax")
])
model.compile(optimizer = tf.keras.optimizers.SGD(lr = 0.01, momentum = 0.9), loss = "sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size = 32, epochs=10, verbose = 1, validation_data = (test_images, test_labels))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/10
# 1875/1875 [==============================] - 80s 42ms/step - loss: 0.1714 - accuracy: 0.9484 - val_loss: 0.0529 - val_accuracy: 0.9833
# Epoch 2/10
# 1875/1875 [==============================] - 78s 41ms/step - loss: 0.0457 - accuracy: 0.9861 - val_loss: 0.0441 - val_accuracy: 0.9858
# Epoch 3/10
# 1875/1875 [==============================] - 77s 41ms/step - loss: 0.0299 - accuracy: 0.9909 - val_loss: 0.0403 - val_accuracy: 0.9861
# Epoch 4/10
# 1875/1875 [==============================] - 78s 42ms/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.0366 - val_accuracy: 0.9886
# Epoch 5/10
# 1875/1875 [==============================] - 78s 42ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.0396 - val_accuracy: 0.9871
# Epoch 6/10
# ...

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print("Accuracy =  %2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0403 - accuracy: 0.9899
# Accuracy =  98.989999

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

# %%
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape(60000, 28, 28, 1)
test_images = test_images.reshape(10000, 28, 28, 1)

train_images, test_images = train_images / 255.0, test_images / 255.0

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation = "relu", input_shape =(28,28,1)),
    tf.keras.layers.Conv2D(64, (3,3), activation = "relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation = "relu"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation = "softmax")
])
model.compile(optimizer = tf.keras.optimizers.SGD(lr = 0.01, momentum = 0.9), loss = "sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size = 32, epochs=15, verbose = 1, validation_data = (test_images, test_labels))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/15
# 1875/1875 [==============================] - 93s 49ms/step - loss: 0.3123 - accuracy: 0.9024 - val_loss: 0.0596 - val_accuracy: 0.9806
# Epoch 2/15
# 1875/1875 [==============================] - 83s 44ms/step - loss: 0.1162 - accuracy: 0.9657 - val_loss: 0.0518 - val_accuracy: 0.9824
# Epoch 3/15
# 1875/1875 [==============================] - 83s 44ms/step - loss: 0.0886 - accuracy: 0.9735 - val_loss: 0.0401 - val_accuracy: 0.9872
# Epoch 4/15
# 1875/1875 [==============================] - 82s 44ms/step - loss: 0.0726 - accuracy: 0.9779 - val_loss: 0.0339 - val_accuracy: 0.9881
# Epoch 5/15
# 1875/1875 [==============================] - 83s 44ms/step - loss: 0.0635 - accuracy: 0.9807 - val_loss: 0.0313 - val_accuracy: 0.9900
# Epoch 6/15
# ...

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print("Accuracy =  %2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0258 - accuracy: 0.9926
# Accuracy =  99.260002

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation = "relu", input_shape =(28,28,1)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, (3,3), activation = "relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = "relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation = "softmax")
])
model.compile(optimizer = tf.keras.optimizers.SGD(lr = 0.01, momentum = 0.9), loss = "sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size = 32, epochs=5, verbose = 1, validation_data = (test_images, test_labels))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/5
# 1875/1875 [==============================] - 106s 56ms/step - loss: 0.0976 - accuracy: 0.9703 - val_loss: 0.0455 - val_accuracy: 0.9854
# Epoch 2/5
# 1875/1875 [==============================] - 107s 57ms/step - loss: 0.0364 - accuracy: 0.9887 - val_loss: 0.0327 - val_accuracy: 0.9897
# Epoch 3/5
# 1875/1875 [==============================] - 107s 57ms/step - loss: 0.0224 - accuracy: 0.9935 - val_loss: 0.0273 - val_accuracy: 0.9914
# Epoch 4/5
# 1875/1875 [==============================] - 108s 57ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.0283 - val_accuracy: 0.9911
# Epoch 5/5
# 1875/1875 [==============================] - 109s 58ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0268 - val_accuracy: 0.9915

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print("Accuracy =  %2f" % (accuracy*100))
# Out:
# 313/313 [==============================] - 3s 11ms/step - loss: 0.0268 - accuracy: 0.9915
# Accuracy =  99.150002
